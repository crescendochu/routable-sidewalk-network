# %%
import geopandas as gpd
import pandas as pd
import numpy as np

# %% [markdown]
# # User group 1

# %%
#read in the cleaned pedestrian data
pedestrian_network = gpd.read_file('../data/cleaned-pednetwork/cleaned-pednetwork-full/cleaned-pednetwork-full.shp')

# %%
pedestrian_network
# Out:
#        pednet_id        osm_id  type    fclass crossing_t  \
# 0              0  1.000034e+09   ped  crossing          m
# 1              1  1.000034e+09   ped   footway          0
# 2              2  1.000034e+09   ped   footway          0
# 3              3  1.005452e+09   ped     steps          0
# 4              4  1.005641e+09   ped     steps          0
# ...          ...           ...   ...       ...        ...
# 34903      34903  1.134447e+09   ped   footway          0
# 34904      34904  1.134447e+09   ped   footway          0
# 34905      34905  1.134447e+09   ped   footway          0
# 34906      34906  1.024999e+09   ped   footway          0
# 34907      34907  4.150069e+07  road  cycleway          0
#
#                                                 geometry
# 0      LINESTRING (1277935.510 238384.953, 1277942.83...
# 1      LINESTRING (1277978.830 238310.174, 1277966.39...
# 2      LINESTRING (1278374.334 238398.460, 1278317.32...
# 3      LINESTRING (1284223.335 235156.549, 1284211.29...
# 4      LINESTRING (1266761.001 234328.359, 1266840.43...
# ...                                                  ...
# 34903  LINESTRING (1267248.184 241235.408, 1267249.61...
# 34904  LINESTRING (1267553.008 238568.697, 1267527.45...
# 34905  LINESTRING (1266704.206 239161.117, 1266715.01...
# 34906  LINESTRING (1266724.989 239254.908, 1266729.96...
# 34907  LINESTRING (1267617.340 238772.178, 1267593.56...
#
# [34908 rows x 6 columns]

# %% [markdown]
# # Sidewalks

# %% [markdown]
# ## 1. Waytype

# %%
pedestrian_network['fclass'].unique()
# Out:
# array(['crossing', 'footway', 'steps', 'pedestrian', 'path', 'track',
#        'service', 'm_footway', 'residential', 'm_service', 'cycleway',
#        'tertiary', 'secondary', 'trunk', 'primary'], dtype=object)

# %%
#create a mapping of the fclass to waytype weight
waytype_weight_dict = {
    'service': 1,
    'm_service': 1,
    'residential': 1,
    'tertiary': 2,
    'cycleway': 1,
}

# %%
pedestrian_network['waytype_w'] = pedestrian_network['fclass'].map(waytype_weight_dict).fillna(1).astype(float)

# %% [markdown]
# ## 2. Sidewalk width

# %%
# read in the sidewalk width data
sidewalk_width = pd.read_csv('../data/pednetwork-attributes/sidewalks/paving-and-width.csv')

# %%
pedestrian_network
# Out:
#        pednet_id        osm_id  type    fclass crossing_t  \
# 0              0  1.000034e+09   ped  crossing          m
# 1              1  1.000034e+09   ped   footway          0
# 2              2  1.000034e+09   ped   footway          0
# 3              3  1.005452e+09   ped     steps          0
# 4              4  1.005641e+09   ped     steps          0
# ...          ...           ...   ...       ...        ...
# 34903      34903  1.134447e+09   ped   footway          0
# 34904      34904  1.134447e+09   ped   footway          0
# 34905      34905  1.134447e+09   ped   footway          0
# 34906      34906  1.024999e+09   ped   footway          0
# 34907      34907  4.150069e+07  road  cycleway          0
#
#                                                 geometry  waytype_w
# 0      LINESTRING (1277935.510 238384.953, 1277942.83...        1.0
# 1      LINESTRING (1277978.830 238310.174, 1277966.39...        1.0
# 2      LINESTRING (1278374.334 238398.460, 1278317.32...        1.0
# 3      LINESTRING (1284223.335 235156.549, 1284211.29...        1.0
# 4      LINESTRING (1266761.001 234328.359, 1266840.43...        1.0
# ...                                                  ...        ...
# 34903  LINESTRING (1267248.184 241235.408, 1267249.61...        1.0
# 34904  LINESTRING (1267553.008 238568.697, 1267527.45...        1.0
# 34905  LINESTRING (1266704.206 239161.117, 1266715.01...        1.0
# 34906  LINESTRING (1266724.989 239254.908, 1266729.96...        1.0
# 34907  LINESTRING (1267617.340 238772.178, 1267593.56...        1.0
#
# [34908 rows x 7 columns]

# %%
#join on pednet_id
pedestrian_network = pedestrian_network.merge(sidewalk_width, on='pednet_id', how='left')

# %%
pedestrian_network
# Out:
#        pednet_id        osm_id  type    fclass crossing_t  \
# 0              0  1.000034e+09   ped  crossing          m
# 1              1  1.000034e+09   ped   footway          0
# 2              2  1.000034e+09   ped   footway          0
# 3              3  1.005452e+09   ped     steps          0
# 4              4  1.005641e+09   ped     steps          0
# ...          ...           ...   ...       ...        ...
# 34903      34903  1.134447e+09   ped   footway          0
# 34904      34904  1.134447e+09   ped   footway          0
# 34905      34905  1.134447e+09   ped   footway          0
# 34906      34906  1.024999e+09   ped   footway          0
# 34907      34907  4.150069e+07  road  cycleway          0
#
#                                                 geometry  waytype_w  width  \
# 0      LINESTRING (1277935.510 238384.953, 1277942.83...        1.0    NaN
# 1      LINESTRING (1277978.830 238310.174, 1277966.39...        1.0   72.0
# 2      LINESTRING (1278374.334 238398.460, 1278317.32...        1.0   61.0
# 3      LINESTRING (1284223.335 235156.549, 1284211.29...        1.0   72.0
# 4      LINESTRING (1266761.001 234328.359, 1266840.43...        1.0   72.0
# ...                                                  ...        ...    ...
# 34903  LINESTRING (1267248.184 241235.408, 1267249.61...        1.0    NaN
# 34904  LINESTRING (1267553.008 238568.697, 1267527.45...        1.0    NaN
# 34905  LINESTRING (1266704.206 239161.117, 1266715.01...        1.0    NaN
# 34906  LINESTRING (1266724.989 239254.908, 1266729.96...        1.0    NaN
# 34907  LINESTRING (1267617.340 238772.178, 1267593.56...        1.0    NaN
#
#       surface_t
# 0           NaN
# 1      concrete
# 2      concrete
# 3      concrete
# 4      concrete
# ...         ...
# 34903       NaN
# 34904       NaN
# 34905       NaN
# 34906       NaN
# 34907       NaN
#
# [34908 rows x 9 columns]

# %%
pedestrian_network['width_w'] = pedestrian_network['width'].apply(lambda x: 1 if pd.isna(x) else (1 if x >= 48 else 1.5))

# %% [markdown]
# ## 3. Sidewalk surface type

# %%
pedestrian_network['surface_t'].unique()
# Out:
# array([nan, 'concrete', 'gravel', 'brick', 'asphalt'], dtype=object)

# %%
#craete a mapping of the surface type to surface weight
surface_weight_dict = {
    'concrete': 1,
    'asphalt': 1,
    'brick': 1.5,
    'gravel': 2,
}

# %%
#map the surface type to the surface weight
pedestrian_network['surface_w'] = pedestrian_network['surface_t'].map(surface_weight_dict).fillna(1).astype(float)

# %% [markdown]
# ## 4. Number of steps

# %%
# read in the number of steps data
number_of_steps = pd.read_csv('../data/pednetwork-attributes/sidewalks/number-of-steps.csv')

# %%
#join on pednet_id
pedestrian_network = pedestrian_network.merge(number_of_steps, on='pednet_id', how='left')

# %%
pedestrian_network
# Out:
#        pednet_id        osm_id  type    fclass crossing_t  \
# 0              0  1.000034e+09   ped  crossing          m
# 1              1  1.000034e+09   ped   footway          0
# 2              2  1.000034e+09   ped   footway          0
# 3              3  1.005452e+09   ped     steps          0
# 4              4  1.005641e+09   ped     steps          0
# ...          ...           ...   ...       ...        ...
# 34903      34903  1.134447e+09   ped   footway          0
# 34904      34904  1.134447e+09   ped   footway          0
# 34905      34905  1.134447e+09   ped   footway          0
# 34906      34906  1.024999e+09   ped   footway          0
# 34907      34907  4.150069e+07  road  cycleway          0
#
#                                                 geometry  waytype_w  width  \
# 0      LINESTRING (1277935.510 238384.953, 1277942.83...        1.0    NaN
# 1      LINESTRING (1277978.830 238310.174, 1277966.39...        1.0   72.0
# 2      LINESTRING (1278374.334 238398.460, 1278317.32...        1.0   61.0
# 3      LINESTRING (1284223.335 235156.549, 1284211.29...        1.0   72.0
# 4      LINESTRING (1266761.001 234328.359, 1266840.43...        1.0   72.0
# ...                                                  ...        ...    ...
# 34903  LINESTRING (1267248.184 241235.408, 1267249.61...        1.0    NaN
# 34904  LINESTRING (1267553.008 238568.697, 1267527.45...        1.0    NaN
# 34905  LINESTRING (1266704.206 239161.117, 1266715.01...        1.0    NaN
# 34906  LINESTRING (1266724.989 239254.908, 1266729.96...        1.0    NaN
# 34907  LINESTRING (1267617.340 238772.178, 1267593.56...        1.0    NaN
#
#       surface_t  width_w  surface_w  number-of-steps
# 0           NaN      1.0        1.0              NaN
# 1      concrete      1.0        1.0              NaN
# 2      concrete      1.0        1.0              NaN
# 3      concrete      1.0        1.0              1.0
# 4      concrete      1.0        1.0              5.0
# ...         ...      ...        ...              ...
# 34903       NaN      1.0        1.0              NaN
# 34904       NaN      1.0        1.0              NaN
# 34905       NaN      1.0        1.0              NaN
# 34906       NaN      1.0        1.0              NaN
# 34907       NaN      1.0        1.0              NaN
#
# [34908 rows x 12 columns]

# %%
def calculate_steps_w(steps):
    if pd.isna(steps):
        return 1
    elif steps < 5:
        return 2
    elif 5 <= steps < 10:
        return 3
    elif steps >= 10:
        return 5

# %%
#want to convert to steps_w Nan is 1, < 5 is 2, >=5 < 10 is 3, >=10 is 5
pedestrian_network['steps_w'] = pedestrian_network['number-of-steps'].apply(calculate_steps_w).astype(float)

# %%
pedestrian_network
# Out:
#        pednet_id        osm_id  type    fclass crossing_t  \
# 0              0  1.000034e+09   ped  crossing          m
# 1              1  1.000034e+09   ped   footway          0
# 2              2  1.000034e+09   ped   footway          0
# 3              3  1.005452e+09   ped     steps          0
# 4              4  1.005641e+09   ped     steps          0
# ...          ...           ...   ...       ...        ...
# 34903      34903  1.134447e+09   ped   footway          0
# 34904      34904  1.134447e+09   ped   footway          0
# 34905      34905  1.134447e+09   ped   footway          0
# 34906      34906  1.024999e+09   ped   footway          0
# 34907      34907  4.150069e+07  road  cycleway          0
#
#                                                 geometry  waytype_w  width  \
# 0      LINESTRING (1277935.510 238384.953, 1277942.83...        1.0    NaN
# 1      LINESTRING (1277978.830 238310.174, 1277966.39...        1.0   72.0
# 2      LINESTRING (1278374.334 238398.460, 1278317.32...        1.0   61.0
# 3      LINESTRING (1284223.335 235156.549, 1284211.29...        1.0   72.0
# 4      LINESTRING (1266761.001 234328.359, 1266840.43...        1.0   72.0
# ...                                                  ...        ...    ...
# 34903  LINESTRING (1267248.184 241235.408, 1267249.61...        1.0    NaN
# 34904  LINESTRING (1267553.008 238568.697, 1267527.45...        1.0    NaN
# 34905  LINESTRING (1266704.206 239161.117, 1266715.01...        1.0    NaN
# 34906  LINESTRING (1266724.989 239254.908, 1266729.96...        1.0    NaN
# 34907  LINESTRING (1267617.340 238772.178, 1267593.56...        1.0    NaN
#
#       surface_t  width_w  surface_w  number-of-steps  steps_w
# 0           NaN      1.0        1.0              NaN      1.0
# 1      concrete      1.0        1.0              NaN      1.0
# 2      concrete      1.0        1.0              NaN      1.0
# 3      concrete      1.0        1.0              1.0      2.0
# 4      concrete      1.0        1.0              5.0      3.0
# ...         ...      ...        ...              ...      ...
# 34903       NaN      1.0        1.0              NaN      1.0
# 34904       NaN      1.0        1.0              NaN      1.0
# 34905       NaN      1.0        1.0              NaN      1.0
# 34906       NaN      1.0        1.0              NaN      1.0
# 34907       NaN      1.0        1.0              NaN      1.0
#
# [34908 rows x 13 columns]

# %% [markdown]
# # Crossings

# %%
#read in crossing traffic flow data
crossing_traffic_flow = pd.read_csv('../data/pednetwork-attributes/crosswalks/crossings-traffic-flow.csv')

# %%
# join on pednet_id
pedestrian_network = pedestrian_network.merge(crossing_traffic_flow, on='pednet_id', how='left')

# %%
pedestrian_network
# Out:
#        pednet_id        osm_id  type    fclass crossing_t  \
# 0              0  1.000034e+09   ped  crossing          m
# 1              1  1.000034e+09   ped   footway          0
# 2              2  1.000034e+09   ped   footway          0
# 3              3  1.005452e+09   ped     steps          0
# 4              4  1.005641e+09   ped     steps          0
# ...          ...           ...   ...       ...        ...
# 34903      34903  1.134447e+09   ped   footway          0
# 34904      34904  1.134447e+09   ped   footway          0
# 34905      34905  1.134447e+09   ped   footway          0
# 34906      34906  1.024999e+09   ped   footway          0
# 34907      34907  4.150069e+07  road  cycleway          0
#
#                                                 geometry  waytype_w  width  \
# 0      LINESTRING (1277935.510 238384.953, 1277942.83...        1.0    NaN
# 1      LINESTRING (1277978.830 238310.174, 1277966.39...        1.0   72.0
# 2      LINESTRING (1278374.334 238398.460, 1278317.32...        1.0   61.0
# 3      LINESTRING (1284223.335 235156.549, 1284211.29...        1.0   72.0
# 4      LINESTRING (1266761.001 234328.359, 1266840.43...        1.0   72.0
# ...                                                  ...        ...    ...
# 34903  LINESTRING (1267248.184 241235.408, 1267249.61...        1.0    NaN
# 34904  LINESTRING (1267553.008 238568.697, 1267527.45...        1.0    NaN
# 34905  LINESTRING (1266704.206 239161.117, 1266715.01...        1.0    NaN
# 34906  LINESTRING (1266724.989 239254.908, 1266729.96...        1.0    NaN
# 34907  LINESTRING (1267617.340 238772.178, 1267593.56...        1.0    NaN
#
#       surface_t  width_w  surface_w  number-of-steps  steps_w traffic_flow
# 0           NaN      1.0        1.0              NaN      1.0          low
# 1      concrete      1.0        1.0              NaN      1.0          NaN
# 2      concrete      1.0        1.0              NaN      1.0          NaN
# 3      concrete      1.0        1.0              1.0      2.0          NaN
# 4      concrete      1.0        1.0              5.0      3.0          NaN
# ...         ...      ...        ...              ...      ...          ...
# 34903       NaN      1.0        1.0              NaN      1.0          NaN
# 34904       NaN      1.0        1.0              NaN      1.0          NaN
# 34905       NaN      1.0        1.0              NaN      1.0          NaN
# 34906       NaN      1.0        1.0              NaN      1.0          NaN
# 34907       NaN      1.0        1.0              NaN      1.0          NaN
#
# [34908 rows x 14 columns]

# %%
def calculate_crossing_w(row):
    if row['crossing_t'] == 'm':
        if row['traffic_flow'] == 'low':
            return 1
        elif row['traffic_flow'] == 'mid':
            return 1.5
        elif row['traffic_flow'] == 'high':
            return 2
    if row['crossing_t'] == 'u':
        if row['traffic_flow'] == 'low':
            return 1
        elif row['traffic_flow'] == 'mid':
            return 2
        elif row['traffic_flow'] == 'high':
            return 4
    return 1

# %%
pedestrian_network['crossing_w'] = pedestrian_network.apply(calculate_crossing_w, axis=1).astype(float)

# %% [markdown]
# # Calculate length based on weight

# %%
# create a new column for the length of the pedestrian network
pedestrian_network['length'] = pedestrian_network['geometry'].length

# %%
#create a column for ['weighted_length'] = ['length'] * ['waytype_w'] * ['width_w'] * ['surface_w'] * ['steps_w'] * ['crossing_w']
pedestrian_network['w_length'] = pedestrian_network['length'] * pedestrian_network['waytype_w'] * pedestrian_network['width_w'] * pedestrian_network['surface_w'] * pedestrian_network['steps_w'] * pedestrian_network['crossing_w']

# %%
pedestrian_network
# Out:
#        pednet_id        osm_id  type    fclass crossing_t  \
# 0              0  1.000034e+09   ped  crossing          m
# 1              1  1.000034e+09   ped   footway          0
# 2              2  1.000034e+09   ped   footway          0
# 3              3  1.005452e+09   ped     steps          0
# 4              4  1.005641e+09   ped     steps          0
# ...          ...           ...   ...       ...        ...
# 34903      34903  1.134447e+09   ped   footway          0
# 34904      34904  1.134447e+09   ped   footway          0
# 34905      34905  1.134447e+09   ped   footway          0
# 34906      34906  1.024999e+09   ped   footway          0
# 34907      34907  4.150069e+07  road  cycleway          0
#
#                                                 geometry  waytype_w  width  \
# 0      LINESTRING (1277935.510 238384.953, 1277942.83...        1.0    NaN
# 1      LINESTRING (1277978.830 238310.174, 1277966.39...        1.0   72.0
# 2      LINESTRING (1278374.334 238398.460, 1278317.32...        1.0   61.0
# 3      LINESTRING (1284223.335 235156.549, 1284211.29...        1.0   72.0
# 4      LINESTRING (1266761.001 234328.359, 1266840.43...        1.0   72.0
# ...                                                  ...        ...    ...
# 34903  LINESTRING (1267248.184 241235.408, 1267249.61...        1.0    NaN
# 34904  LINESTRING (1267553.008 238568.697, 1267527.45...        1.0    NaN
# 34905  LINESTRING (1266704.206 239161.117, 1266715.01...        1.0    NaN
# 34906  LINESTRING (1266724.989 239254.908, 1266729.96...        1.0    NaN
# 34907  LINESTRING (1267617.340 238772.178, 1267593.56...        1.0    NaN
#
#       surface_t  width_w  surface_w  number-of-steps  steps_w traffic_flow  \
# 0           NaN      1.0        1.0              NaN      1.0          low
# 1      concrete      1.0        1.0              NaN      1.0          NaN
# 2      concrete      1.0        1.0              NaN      1.0          NaN
# 3      concrete      1.0        1.0              1.0      2.0          NaN
# 4      concrete      1.0        1.0              5.0      3.0          NaN
# ...         ...      ...        ...              ...      ...          ...
# 34903       NaN      1.0        1.0              NaN      1.0          NaN
# 34904       NaN      1.0        1.0              NaN      1.0          NaN
# 34905       NaN      1.0        1.0              NaN      1.0          NaN
# 34906       NaN      1.0        1.0              NaN      1.0          NaN
# 34907       NaN      1.0        1.0              NaN      1.0          NaN
#
#        crossing_w       length     w_length
# 0             1.0    71.188703    71.188703
# 1             1.0    16.675574    16.675574
# 2             1.0   458.294269   458.294269
# 3             1.0    17.555658    35.111317
# 4             1.0    79.474146   238.422439
# ...           ...          ...          ...
# 34903         1.0  2229.595778  2229.595778
# 34904         1.0  1089.021370  1089.021370
# 34905         1.0  1019.770904  1019.770904
# 34906         1.0  1309.756046  1309.756046
# 34907         1.0   847.413430   847.413430
#
# [34908 rows x 17 columns]

# %%
# new column that calculates the ratio change of the weighted length
pedestrian_network['w_length_r'] = pedestrian_network['w_length']/pedestrian_network['length']

# %%
#new column that calculates the absolute difference between the weighted length and the length
pedestrian_network['w_length_d'] = pedestrian_network['w_length'] - pedestrian_network['length']

# %%
pedestrian_network.head()
# Out:
#    pednet_id        osm_id type    fclass crossing_t  \
# 0          0  1.000034e+09  ped  crossing          m
# 1          1  1.000034e+09  ped   footway          0
# 2          2  1.000034e+09  ped   footway          0
# 3          3  1.005452e+09  ped     steps          0
# 4          4  1.005641e+09  ped     steps          0
#
#                                             geometry  waytype_w  width  \
# 0  LINESTRING (1277935.510 238384.953, 1277942.83...        1.0    NaN
# 1  LINESTRING (1277978.830 238310.174, 1277966.39...        1.0   72.0
# 2  LINESTRING (1278374.334 238398.460, 1278317.32...        1.0   61.0
# 3  LINESTRING (1284223.335 235156.549, 1284211.29...        1.0   72.0
# 4  LINESTRING (1266761.001 234328.359, 1266840.43...        1.0   72.0
#
#   surface_t  width_w  surface_w  number-of-steps  steps_w traffic_flow  \
# 0       NaN      1.0        1.0              NaN      1.0          low
# 1  concrete      1.0        1.0              NaN      1.0          NaN
# 2  concrete      1.0        1.0              NaN      1.0          NaN
# 3  concrete      1.0        1.0              1.0      2.0          NaN
# 4  concrete      1.0        1.0              5.0      3.0          NaN
#
#    crossing_w      length    w_length  w_length_r  w_length_d
# 0         1.0   71.188703   71.188703         1.0    0.000000
# 1         1.0   16.675574   16.675574         1.0    0.000000
# 2         1.0  458.294269  458.294269         1.0    0.000000
# 3         1.0   17.555658   35.111317         2.0   17.555658
# 4         1.0   79.474146  238.422439         3.0  158.948293

# %%
pedestrian_network = pedestrian_network[['pednet_id', 'waytype_w', 'width_w', 'surface_w', 'steps_w', 'crossing_w', 'length', 'w_length', 'w_length_r', 'w_length_d', 'geometry']]

# %%
#pedestrian_network .explore(column = 'w_length_r', tiles="cartodbpositron")

# %%
#save the data to shapefile
pedestrian_network.to_file('../data/weighted-network/user-group-1/user-group-1-weighted-network.shp')

# %%
#save also as geojson
pedestrian_network.to_file('../data/paired-data/ug1/network_ug1.geojson', driver='GeoJSON')
