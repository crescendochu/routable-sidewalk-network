# %%
import geopandas as gpd
import pandas as pd
import numpy as np

# %% [markdown]
# # User group 1

# %%
#read in the cleaned pedestrian data
pedestrian_network = gpd.read_file('../data/cleaned-pednetwork/cleaned-pednetwork-full/cleaned-pednetwork-full.shp')

# %%
pedestrian_network
# Out:
#        pednet_id  pednet_pid        osm_id  type    fclass crossing_t  \
# 0            0.0           0  1.000034e+09   ped  crossing          m
# 1            1.0           1  1.000034e+09   ped   footway          0
# 2            2.0           2  1.000034e+09   ped   footway          0
# 3            3.0           3  1.005452e+09   ped     steps          0
# 4            4.0           4  1.005641e+09   ped     steps          0
# ...          ...         ...           ...   ...       ...        ...
# 34928    32959.0       34924  1.124353e+09   ped   footway          0
# 34929    32960.0       34925  1.700162e+08  road   service          0
# 34930    32961.0       34926  1.700162e+08  road   service          0
# 34931    32962.0       34927  6.423613e+06  road   service          0
# 34932    32963.0       34928  1.124353e+09   ped   footway          0
#
#           z-start       z-end  \
# 0       15.400000   16.200001
# 1       16.200001   16.200001
# 2       10.500000   16.200001
# 3       11.600000   11.600000
# 4      124.599998  118.900002
# ...           ...         ...
# 34928   68.199997   68.199997
# 34929   65.099998   62.700001
# 34930   62.700001   65.099998
# 34931   61.599998   62.700001
# 34932   68.199997   68.199997
#
#                                                 geometry
# 0      LINESTRING (1277935.51 238384.953, 1277942.83 ...
# 1      LINESTRING (1277978.83 238310.174, 1277966.394...
# 2      LINESTRING (1278374.334 238398.46, 1278317.326...
# 3      LINESTRING (1284223.335 235156.549, 1284211.29...
# 4      LINESTRING (1266761.001 234328.359, 1266840.43...
# ...                                                  ...
# 34928  LINESTRING (1262631.523 239983.092, 1262641.40...
# 34929  LINESTRING (1262862.932 240024.343, 1262868.78...
# 34930  LINESTRING (1262918.344 240036.228, 1262921.4 ...
# 34931  LINESTRING (1263190.244 239825.195, 1263057.2 ...
# 34932  LINESTRING (1262670.912 239978.987, 1262674.63...
#
# [34933 rows x 9 columns]

# %% [markdown]
# # Sidewalks

# %% [markdown]
# ## 1. Waytype

# %%
pedestrian_network['fclass'].unique()
# Out:
# array(['crossing', 'footway', 'steps', 'pedestrian', 'path', 'track',
#        'service', 'm_footway', 'residential', 'm_service', 'cycleway',
#        'tertiary', 'secondary', 'trunk', 'primary', '0'], dtype=object)

# %%
#create a mapping of the fclass to waytype weight
waytype_weight_dict = {
    'service': 1,
    'm_service': 1,
    'residential': 1,
    'tertiary': 2,
    'cycleway': 1,
}

# %%
pedestrian_network['waytype_w'] = pedestrian_network['fclass'].map(waytype_weight_dict).fillna(1).astype(float)

# %% [markdown]
# ## 2. Sidewalk width

# %%
# read in the sidewalk width data
sidewalk_width = pd.read_csv('../data/pednetwork-attributes/sidewalks/paving-and-width.csv')

# %%
sidewalk_width
# Out:
#        pednet_pid surface_t  width
# 0               0  concrete   72.0
# 1               1  concrete  106.0
# 2               2  concrete   61.0
# 3               3  concrete   72.0
# 4               4  concrete   72.0
# ...           ...       ...    ...
# 34924       34924  concrete   72.0
# 34925       34925  concrete   72.0
# 34926       34926  concrete   72.0
# 34927       34927  concrete   72.0
# 34928       34928  concrete   72.0
#
# [34929 rows x 3 columns]

# %%
pedestrian_network
# Out:
#        pednet_id  pednet_pid        osm_id  type    fclass crossing_t  \
# 0            0.0           0  1.000034e+09   ped  crossing          m
# 1            1.0           1  1.000034e+09   ped   footway          0
# 2            2.0           2  1.000034e+09   ped   footway          0
# 3            3.0           3  1.005452e+09   ped     steps          0
# 4            4.0           4  1.005641e+09   ped     steps          0
# ...          ...         ...           ...   ...       ...        ...
# 34928    32959.0       34924  1.124353e+09   ped   footway          0
# 34929    32960.0       34925  1.700162e+08  road   service          0
# 34930    32961.0       34926  1.700162e+08  road   service          0
# 34931    32962.0       34927  6.423613e+06  road   service          0
# 34932    32963.0       34928  1.124353e+09   ped   footway          0
#
#           z-start       z-end  \
# 0       15.400000   16.200001
# 1       16.200001   16.200001
# 2       10.500000   16.200001
# 3       11.600000   11.600000
# 4      124.599998  118.900002
# ...           ...         ...
# 34928   68.199997   68.199997
# 34929   65.099998   62.700001
# 34930   62.700001   65.099998
# 34931   61.599998   62.700001
# 34932   68.199997   68.199997
#
#                                                 geometry  waytype_w
# 0      LINESTRING (1277935.51 238384.953, 1277942.83 ...        1.0
# 1      LINESTRING (1277978.83 238310.174, 1277966.394...        1.0
# 2      LINESTRING (1278374.334 238398.46, 1278317.326...        1.0
# 3      LINESTRING (1284223.335 235156.549, 1284211.29...        1.0
# 4      LINESTRING (1266761.001 234328.359, 1266840.43...        1.0
# ...                                                  ...        ...
# 34928  LINESTRING (1262631.523 239983.092, 1262641.40...        1.0
# 34929  LINESTRING (1262862.932 240024.343, 1262868.78...        1.0
# 34930  LINESTRING (1262918.344 240036.228, 1262921.4 ...        1.0
# 34931  LINESTRING (1263190.244 239825.195, 1263057.2 ...        1.0
# 34932  LINESTRING (1262670.912 239978.987, 1262674.63...        1.0
#
# [34933 rows x 10 columns]

# %%
#join on pednet_id
pedestrian_network = pedestrian_network.merge(sidewalk_width, on='pednet_pid', how='left')

# %%
pedestrian_network
# Out:
#        pednet_id  pednet_pid        osm_id  type    fclass crossing_t  \
# 0            0.0           0  1.000034e+09   ped  crossing          m
# 1            1.0           1  1.000034e+09   ped   footway          0
# 2            2.0           2  1.000034e+09   ped   footway          0
# 3            3.0           3  1.005452e+09   ped     steps          0
# 4            4.0           4  1.005641e+09   ped     steps          0
# ...          ...         ...           ...   ...       ...        ...
# 34928    32959.0       34924  1.124353e+09   ped   footway          0
# 34929    32960.0       34925  1.700162e+08  road   service          0
# 34930    32961.0       34926  1.700162e+08  road   service          0
# 34931    32962.0       34927  6.423613e+06  road   service          0
# 34932    32963.0       34928  1.124353e+09   ped   footway          0
#
#           z-start       z-end  \
# 0       15.400000   16.200001
# 1       16.200001   16.200001
# 2       10.500000   16.200001
# 3       11.600000   11.600000
# 4      124.599998  118.900002
# ...           ...         ...
# 34928   68.199997   68.199997
# 34929   65.099998   62.700001
# 34930   62.700001   65.099998
# 34931   61.599998   62.700001
# 34932   68.199997   68.199997
#
#                                                 geometry  waytype_w surface_t  \
# 0      LINESTRING (1277935.51 238384.953, 1277942.83 ...        1.0  concrete
# 1      LINESTRING (1277978.83 238310.174, 1277966.394...        1.0  concrete
# 2      LINESTRING (1278374.334 238398.46, 1278317.326...        1.0  concrete
# 3      LINESTRING (1284223.335 235156.549, 1284211.29...        1.0  concrete
# 4      LINESTRING (1266761.001 234328.359, 1266840.43...        1.0  concrete
# ...                                                  ...        ...       ...
# 34928  LINESTRING (1262631.523 239983.092, 1262641.40...        1.0  concrete
# 34929  LINESTRING (1262862.932 240024.343, 1262868.78...        1.0  concrete
# 34930  LINESTRING (1262918.344 240036.228, 1262921.4 ...        1.0  concrete
# 34931  LINESTRING (1263190.244 239825.195, 1263057.2 ...        1.0  concrete
# 34932  LINESTRING (1262670.912 239978.987, 1262674.63...        1.0  concrete
#
#        width
# 0       72.0
# 1      106.0
# 2       61.0
# 3       72.0
# 4       72.0
# ...      ...
# 34928   72.0
# 34929   72.0
# 34930   72.0
# 34931   72.0
# 34932   72.0
#
# [34933 rows x 12 columns]

# %%
pedestrian_network['width_w'] = pedestrian_network['width'].apply(lambda x: 1 if pd.isna(x) else (1 if x >= 48 else 1.5))

# %% [markdown]
# ## 3. Sidewalk surface type

# %%
pedestrian_network['surface_t'].unique()
# Out:
# array(['concrete', 'gravel', 'asphalt', 'brick'], dtype=object)

# %%
#craete a mapping of the surface type to surface weight
surface_weight_dict = {
    'concrete': 1,
    'asphalt': 1,
    'brick': 1.5,
    'gravel': 2,
}

# %%
#map the surface type to the surface weight
pedestrian_network['surface_w'] = pedestrian_network['surface_t'].map(surface_weight_dict).fillna(1).astype(float)

# %% [markdown]
# ## 4. Number of steps

# %%
# read in the number of steps data
number_of_steps = pd.read_csv('../data/pednetwork-attributes/sidewalks/number-of-steps.csv')

# %%
#join on pednet_id
pedestrian_network = pedestrian_network.merge(number_of_steps, on='pednet_id', how='left')

# %%
pedestrian_network
# Out:
#        pednet_id  pednet_pid        osm_id  type    fclass crossing_t  \
# 0            0.0           0  1.000034e+09   ped  crossing          m
# 1            1.0           1  1.000034e+09   ped   footway          0
# 2            2.0           2  1.000034e+09   ped   footway          0
# 3            3.0           3  1.005452e+09   ped     steps          0
# 4            4.0           4  1.005641e+09   ped     steps          0
# ...          ...         ...           ...   ...       ...        ...
# 34928    32959.0       34924  1.124353e+09   ped   footway          0
# 34929    32960.0       34925  1.700162e+08  road   service          0
# 34930    32961.0       34926  1.700162e+08  road   service          0
# 34931    32962.0       34927  6.423613e+06  road   service          0
# 34932    32963.0       34928  1.124353e+09   ped   footway          0
#
#           z-start       z-end  \
# 0       15.400000   16.200001
# 1       16.200001   16.200001
# 2       10.500000   16.200001
# 3       11.600000   11.600000
# 4      124.599998  118.900002
# ...           ...         ...
# 34928   68.199997   68.199997
# 34929   65.099998   62.700001
# 34930   62.700001   65.099998
# 34931   61.599998   62.700001
# 34932   68.199997   68.199997
#
#                                                 geometry  waytype_w surface_t  \
# 0      LINESTRING (1277935.51 238384.953, 1277942.83 ...        1.0  concrete
# 1      LINESTRING (1277978.83 238310.174, 1277966.394...        1.0  concrete
# 2      LINESTRING (1278374.334 238398.46, 1278317.326...        1.0  concrete
# 3      LINESTRING (1284223.335 235156.549, 1284211.29...        1.0  concrete
# 4      LINESTRING (1266761.001 234328.359, 1266840.43...        1.0  concrete
# ...                                                  ...        ...       ...
# 34928  LINESTRING (1262631.523 239983.092, 1262641.40...        1.0  concrete
# 34929  LINESTRING (1262862.932 240024.343, 1262868.78...        1.0  concrete
# 34930  LINESTRING (1262918.344 240036.228, 1262921.4 ...        1.0  concrete
# 34931  LINESTRING (1263190.244 239825.195, 1263057.2 ...        1.0  concrete
# 34932  LINESTRING (1262670.912 239978.987, 1262674.63...        1.0  concrete
#
#        width  width_w  surface_w  number-of-steps
# 0       72.0      1.0        1.0              NaN
# 1      106.0      1.0        1.0              NaN
# 2       61.0      1.0        1.0              NaN
# 3       72.0      1.0        1.0              1.0
# 4       72.0      1.0        1.0              5.0
# ...      ...      ...        ...              ...
# 34928   72.0      1.0        1.0              NaN
# 34929   72.0      1.0        1.0              NaN
# 34930   72.0      1.0        1.0              NaN
# 34931   72.0      1.0        1.0              NaN
# 34932   72.0      1.0        1.0              NaN
#
# [34933 rows x 15 columns]

# %%
def calculate_steps_w(steps):
    if pd.isna(steps):
        return 1
    elif steps < 5:
        return 2
    elif 5 <= steps < 10:
        return 3
    elif steps >= 10:
        return 5

# %%
#want to convert to steps_w Nan is 1, < 5 is 2, >=5 < 10 is 3, >=10 is 5
pedestrian_network['steps_w'] = pedestrian_network['number-of-steps'].apply(calculate_steps_w).astype(float)

# %%
pedestrian_network
# Out:
#        pednet_id  pednet_pid        osm_id  type    fclass crossing_t  \
# 0            0.0           0  1.000034e+09   ped  crossing          m
# 1            1.0           1  1.000034e+09   ped   footway          0
# 2            2.0           2  1.000034e+09   ped   footway          0
# 3            3.0           3  1.005452e+09   ped     steps          0
# 4            4.0           4  1.005641e+09   ped     steps          0
# ...          ...         ...           ...   ...       ...        ...
# 34928    32959.0       34924  1.124353e+09   ped   footway          0
# 34929    32960.0       34925  1.700162e+08  road   service          0
# 34930    32961.0       34926  1.700162e+08  road   service          0
# 34931    32962.0       34927  6.423613e+06  road   service          0
# 34932    32963.0       34928  1.124353e+09   ped   footway          0
#
#           z-start       z-end  \
# 0       15.400000   16.200001
# 1       16.200001   16.200001
# 2       10.500000   16.200001
# 3       11.600000   11.600000
# 4      124.599998  118.900002
# ...           ...         ...
# 34928   68.199997   68.199997
# 34929   65.099998   62.700001
# 34930   62.700001   65.099998
# 34931   61.599998   62.700001
# 34932   68.199997   68.199997
#
#                                                 geometry  waytype_w surface_t  \
# 0      LINESTRING (1277935.51 238384.953, 1277942.83 ...        1.0  concrete
# 1      LINESTRING (1277978.83 238310.174, 1277966.394...        1.0  concrete
# 2      LINESTRING (1278374.334 238398.46, 1278317.326...        1.0  concrete
# 3      LINESTRING (1284223.335 235156.549, 1284211.29...        1.0  concrete
# 4      LINESTRING (1266761.001 234328.359, 1266840.43...        1.0  concrete
# ...                                                  ...        ...       ...
# 34928  LINESTRING (1262631.523 239983.092, 1262641.40...        1.0  concrete
# 34929  LINESTRING (1262862.932 240024.343, 1262868.78...        1.0  concrete
# 34930  LINESTRING (1262918.344 240036.228, 1262921.4 ...        1.0  concrete
# 34931  LINESTRING (1263190.244 239825.195, 1263057.2 ...        1.0  concrete
# 34932  LINESTRING (1262670.912 239978.987, 1262674.63...        1.0  concrete
#
#        width  width_w  surface_w  number-of-steps  steps_w
# 0       72.0      1.0        1.0              NaN      1.0
# 1      106.0      1.0        1.0              NaN      1.0
# 2       61.0      1.0        1.0              NaN      1.0
# 3       72.0      1.0        1.0              1.0      2.0
# 4       72.0      1.0        1.0              5.0      3.0
# ...      ...      ...        ...              ...      ...
# 34928   72.0      1.0        1.0              NaN      1.0
# 34929   72.0      1.0        1.0              NaN      1.0
# 34930   72.0      1.0        1.0              NaN      1.0
# 34931   72.0      1.0        1.0              NaN      1.0
# 34932   72.0      1.0        1.0              NaN      1.0
#
# [34933 rows x 16 columns]

# %% [markdown]
# ## 5. Slope

# %%
pedestrian_network
# Out:
#        pednet_id  pednet_pid        osm_id  type    fclass crossing_t  \
# 0            0.0           0  1.000034e+09   ped  crossing          m
# 1            1.0           1  1.000034e+09   ped   footway          0
# 2            2.0           2  1.000034e+09   ped   footway          0
# 3            3.0           3  1.005452e+09   ped     steps          0
# 4            4.0           4  1.005641e+09   ped     steps          0
# ...          ...         ...           ...   ...       ...        ...
# 34928    32959.0       34924  1.124353e+09   ped   footway          0
# 34929    32960.0       34925  1.700162e+08  road   service          0
# 34930    32961.0       34926  1.700162e+08  road   service          0
# 34931    32962.0       34927  6.423613e+06  road   service          0
# 34932    32963.0       34928  1.124353e+09   ped   footway          0
#
#           z-start       z-end  \
# 0       15.400000   16.200001
# 1       16.200001   16.200001
# 2       10.500000   16.200001
# 3       11.600000   11.600000
# 4      124.599998  118.900002
# ...           ...         ...
# 34928   68.199997   68.199997
# 34929   65.099998   62.700001
# 34930   62.700001   65.099998
# 34931   61.599998   62.700001
# 34932   68.199997   68.199997
#
#                                                 geometry  waytype_w surface_t  \
# 0      LINESTRING (1277935.51 238384.953, 1277942.83 ...        1.0  concrete
# 1      LINESTRING (1277978.83 238310.174, 1277966.394...        1.0  concrete
# 2      LINESTRING (1278374.334 238398.46, 1278317.326...        1.0  concrete
# 3      LINESTRING (1284223.335 235156.549, 1284211.29...        1.0  concrete
# 4      LINESTRING (1266761.001 234328.359, 1266840.43...        1.0  concrete
# ...                                                  ...        ...       ...
# 34928  LINESTRING (1262631.523 239983.092, 1262641.40...        1.0  concrete
# 34929  LINESTRING (1262862.932 240024.343, 1262868.78...        1.0  concrete
# 34930  LINESTRING (1262918.344 240036.228, 1262921.4 ...        1.0  concrete
# 34931  LINESTRING (1263190.244 239825.195, 1263057.2 ...        1.0  concrete
# 34932  LINESTRING (1262670.912 239978.987, 1262674.63...        1.0  concrete
#
#        width  width_w  surface_w  number-of-steps  steps_w
# 0       72.0      1.0        1.0              NaN      1.0
# 1      106.0      1.0        1.0              NaN      1.0
# 2       61.0      1.0        1.0              NaN      1.0
# 3       72.0      1.0        1.0              1.0      2.0
# 4       72.0      1.0        1.0              5.0      3.0
# ...      ...      ...        ...              ...      ...
# 34928   72.0      1.0        1.0              NaN      1.0
# 34929   72.0      1.0        1.0              NaN      1.0
# 34930   72.0      1.0        1.0              NaN      1.0
# 34931   72.0      1.0        1.0              NaN      1.0
# 34932   72.0      1.0        1.0              NaN      1.0
#
# [34933 rows x 16 columns]

# %%
# add a column for z difference
pedestrian_network['z_d'] = abs(pedestrian_network['z-start'] - pedestrian_network['z-end'])
#change the z_d to meters to feet
pedestrian_network['z_d'] = pedestrian_network['z_d'] * 3.28084

# %%
# create a new column for the length of the pedestrian network
pedestrian_network['length'] = pedestrian_network['geometry'].length

# %%
#calculate the slope in percent
pedestrian_network['slope'] = pedestrian_network['z_d'] / pedestrian_network['length']

# %%
#pedestrian_network.explore(column = 'slope', tiles = 'cartodbpositron', scheme = 'naturalbreaks')

# %%
# add in a slope weight, if slope > 5% then 2, else 1
pedestrian_network['slope_w'] = np.where(pedestrian_network['slope'] > 0.05, 2, 1)

# %% [markdown]
# # Crossings

# %%
#read in crossing traffic flow data
crossing_traffic_flow = pd.read_csv('../data/pednetwork-attributes/crosswalks/crossings-traffic-flow.csv')

# %%
# join on pednet_id
pedestrian_network = pedestrian_network.merge(crossing_traffic_flow, on='pednet_id', how='left')

# %%
pedestrian_network
# Out:
#        pednet_id  pednet_pid        osm_id  type    fclass crossing_t  \
# 0            0.0           0  1.000034e+09   ped  crossing          m
# 1            1.0           1  1.000034e+09   ped   footway          0
# 2            2.0           2  1.000034e+09   ped   footway          0
# 3            3.0           3  1.005452e+09   ped     steps          0
# 4            4.0           4  1.005641e+09   ped     steps          0
# ...          ...         ...           ...   ...       ...        ...
# 34928    32959.0       34924  1.124353e+09   ped   footway          0
# 34929    32960.0       34925  1.700162e+08  road   service          0
# 34930    32961.0       34926  1.700162e+08  road   service          0
# 34931    32962.0       34927  6.423613e+06  road   service          0
# 34932    32963.0       34928  1.124353e+09   ped   footway          0
#
#           z-start       z-end  \
# 0       15.400000   16.200001
# 1       16.200001   16.200001
# 2       10.500000   16.200001
# 3       11.600000   11.600000
# 4      124.599998  118.900002
# ...           ...         ...
# 34928   68.199997   68.199997
# 34929   65.099998   62.700001
# 34930   62.700001   65.099998
# 34931   61.599998   62.700001
# 34932   68.199997   68.199997
#
#                                                 geometry  waytype_w  ...  \
# 0      LINESTRING (1277935.51 238384.953, 1277942.83 ...        1.0  ...
# 1      LINESTRING (1277978.83 238310.174, 1277966.394...        1.0  ...
# 2      LINESTRING (1278374.334 238398.46, 1278317.326...        1.0  ...
# 3      LINESTRING (1284223.335 235156.549, 1284211.29...        1.0  ...
# 4      LINESTRING (1266761.001 234328.359, 1266840.43...        1.0  ...
# ...                                                  ...        ...  ...
# 34928  LINESTRING (1262631.523 239983.092, 1262641.40...        1.0  ...
# 34929  LINESTRING (1262862.932 240024.343, 1262868.78...        1.0  ...
# 34930  LINESTRING (1262918.344 240036.228, 1262921.4 ...        1.0  ...
# 34931  LINESTRING (1263190.244 239825.195, 1263057.2 ...        1.0  ...
# 34932  LINESTRING (1262670.912 239978.987, 1262674.63...        1.0  ...
#
#        width  width_w  surface_w  number-of-steps  steps_w        z_d  \
# 0       72.0      1.0        1.0              NaN      1.0   2.624676
# 1      106.0      1.0        1.0              NaN      1.0   0.000000
# 2       61.0      1.0        1.0              NaN      1.0  18.700791
# 3       72.0      1.0        1.0              1.0      2.0   0.000000
# 4       72.0      1.0        1.0              5.0      3.0  18.700778
# ...      ...      ...        ...              ...      ...        ...
# 34928   72.0      1.0        1.0              NaN      1.0   0.000000
# 34929   72.0      1.0        1.0              NaN      1.0   7.874008
# 34930   72.0      1.0        1.0              NaN      1.0   7.874008
# 34931   72.0      1.0        1.0              NaN      1.0   3.608932
# 34932   72.0      1.0        1.0              NaN      1.0   0.000000
#
#            length     slope  slope_w  traffic_flow
# 0       71.188703  0.036869        1           low
# 1       16.675574  0.000000        1           NaN
# 2      458.294269  0.040805        1           NaN
# 3       17.555658  0.000000        1           NaN
# 4       79.474146  0.235306        2           NaN
# ...           ...       ...      ...           ...
# 34928   10.709117  0.000000        1           NaN
# 34929   60.364828  0.130440        2           NaN
# 34930  155.739448  0.050559        2           NaN
# 34931  344.187381  0.010485        1           NaN
# 34932   22.066759  0.000000        1           NaN
#
# [34933 rows x 21 columns]

# %%
def calculate_crossing_w(row):
    if row['crossing_t'] == 'm':
        if row['traffic_flow'] == 'low':
            return 1
        elif row['traffic_flow'] == 'mid':
            return 1.5
        elif row['traffic_flow'] == 'high':
            return 2
    if row['crossing_t'] == 'u':
        if row['traffic_flow'] == 'low':
            return 1
        elif row['traffic_flow'] == 'mid':
            return 2
        elif row['traffic_flow'] == 'high':
            return 4
    return 1

# %%
pedestrian_network['crossing_w'] = pedestrian_network.apply(calculate_crossing_w, axis=1).astype(float)

# %% [markdown]
# # Calculate length based on weight

# %%
#create a new column for the total weight that is the product of all the weights
pedestrian_network['total_w'] = pedestrian_network['waytype_w'] * pedestrian_network['width_w'] * pedestrian_network['surface_w'] * pedestrian_network['steps_w'] * pedestrian_network['slope_w'] * pedestrian_network['crossing_w']
# if the total weight is greater than 999, set it to 999
pedestrian_network['total_w'] = np.where(pedestrian_network['total_w'] > 999, 999, pedestrian_network['total_w'])

# %%
#create a column for ['weighted_length'] that length * total_w
pedestrian_network['w_length'] = pedestrian_network['length'] * pedestrian_network['total_w']

# %%
pedestrian_network
# Out:
#        pednet_id  pednet_pid        osm_id  type    fclass crossing_t  \
# 0            0.0           0  1.000034e+09   ped  crossing          m
# 1            1.0           1  1.000034e+09   ped   footway          0
# 2            2.0           2  1.000034e+09   ped   footway          0
# 3            3.0           3  1.005452e+09   ped     steps          0
# 4            4.0           4  1.005641e+09   ped     steps          0
# ...          ...         ...           ...   ...       ...        ...
# 34928    32959.0       34924  1.124353e+09   ped   footway          0
# 34929    32960.0       34925  1.700162e+08  road   service          0
# 34930    32961.0       34926  1.700162e+08  road   service          0
# 34931    32962.0       34927  6.423613e+06  road   service          0
# 34932    32963.0       34928  1.124353e+09   ped   footway          0
#
#           z-start       z-end  \
# 0       15.400000   16.200001
# 1       16.200001   16.200001
# 2       10.500000   16.200001
# 3       11.600000   11.600000
# 4      124.599998  118.900002
# ...           ...         ...
# 34928   68.199997   68.199997
# 34929   65.099998   62.700001
# 34930   62.700001   65.099998
# 34931   61.599998   62.700001
# 34932   68.199997   68.199997
#
#                                                 geometry  waytype_w  ...  \
# 0      LINESTRING (1277935.51 238384.953, 1277942.83 ...        1.0  ...
# 1      LINESTRING (1277978.83 238310.174, 1277966.394...        1.0  ...
# 2      LINESTRING (1278374.334 238398.46, 1278317.326...        1.0  ...
# 3      LINESTRING (1284223.335 235156.549, 1284211.29...        1.0  ...
# 4      LINESTRING (1266761.001 234328.359, 1266840.43...        1.0  ...
# ...                                                  ...        ...  ...
# 34928  LINESTRING (1262631.523 239983.092, 1262641.40...        1.0  ...
# 34929  LINESTRING (1262862.932 240024.343, 1262868.78...        1.0  ...
# 34930  LINESTRING (1262918.344 240036.228, 1262921.4 ...        1.0  ...
# 34931  LINESTRING (1263190.244 239825.195, 1263057.2 ...        1.0  ...
# 34932  LINESTRING (1262670.912 239978.987, 1262674.63...        1.0  ...
#
#       number-of-steps  steps_w        z_d      length     slope  slope_w  \
# 0                 NaN      1.0   2.624676   71.188703  0.036869        1
# 1                 NaN      1.0   0.000000   16.675574  0.000000        1
# 2                 NaN      1.0  18.700791  458.294269  0.040805        1
# 3                 1.0      2.0   0.000000   17.555658  0.000000        1
# 4                 5.0      3.0  18.700778   79.474146  0.235306        2
# ...               ...      ...        ...         ...       ...      ...
# 34928             NaN      1.0   0.000000   10.709117  0.000000        1
# 34929             NaN      1.0   7.874008   60.364828  0.130440        2
# 34930             NaN      1.0   7.874008  155.739448  0.050559        2
# 34931             NaN      1.0   3.608932  344.187381  0.010485        1
# 34932             NaN      1.0   0.000000   22.066759  0.000000        1
#
#        traffic_flow  crossing_w  total_w    w_length
# 0               low         1.0      1.0   71.188703
# 1               NaN         1.0      1.0   16.675574
# 2               NaN         1.0      1.0  458.294269
# 3               NaN         1.0      2.0   35.111317
# 4               NaN         1.0      6.0  476.844879
# ...             ...         ...      ...         ...
# 34928           NaN         1.0      1.0   10.709117
# 34929           NaN         1.0      2.0  120.729655
# 34930           NaN         1.0      2.0  311.478896
# 34931           NaN         1.0      1.0  344.187381
# 34932           NaN         1.0      1.0   22.066759
#
# [34933 rows x 24 columns]

# %%
# new column that calculates the ratio change of the weighted length
pedestrian_network['w_length_r'] = pedestrian_network['w_length']/pedestrian_network['length']

# %%
#new column that calculates the absolute difference between the weighted length and the length
pedestrian_network['w_length_d'] = pedestrian_network['w_length'] - pedestrian_network['length']

# %%
pedestrian_network.head()
# Out:
#    pednet_id  pednet_pid        osm_id type    fclass crossing_t     z-start  \
# 0        0.0           0  1.000034e+09  ped  crossing          m   15.400000
# 1        1.0           1  1.000034e+09  ped   footway          0   16.200001
# 2        2.0           2  1.000034e+09  ped   footway          0   10.500000
# 3        3.0           3  1.005452e+09  ped     steps          0   11.600000
# 4        4.0           4  1.005641e+09  ped     steps          0  124.599998
#
#         z-end                                           geometry  waytype_w  \
# 0   16.200001  LINESTRING (1277935.51 238384.953, 1277942.83 ...        1.0
# 1   16.200001  LINESTRING (1277978.83 238310.174, 1277966.394...        1.0
# 2   16.200001  LINESTRING (1278374.334 238398.46, 1278317.326...        1.0
# 3   11.600000  LINESTRING (1284223.335 235156.549, 1284211.29...        1.0
# 4  118.900002  LINESTRING (1266761.001 234328.359, 1266840.43...        1.0
#
#    ...        z_d      length     slope  slope_w  traffic_flow  crossing_w  \
# 0  ...   2.624676   71.188703  0.036869        1           low         1.0
# 1  ...   0.000000   16.675574  0.000000        1           NaN         1.0
# 2  ...  18.700791  458.294269  0.040805        1           NaN         1.0
# 3  ...   0.000000   17.555658  0.000000        1           NaN         1.0
# 4  ...  18.700778   79.474146  0.235306        2           NaN         1.0
#
#    total_w    w_length  w_length_r  w_length_d
# 0      1.0   71.188703         1.0    0.000000
# 1      1.0   16.675574         1.0    0.000000
# 2      1.0  458.294269         1.0    0.000000
# 3      2.0   35.111317         2.0   17.555658
# 4      6.0  476.844879         6.0  397.370732
#
# [5 rows x 26 columns]

# %%
pedestrian_network = pedestrian_network[['pednet_id', 'waytype_w', 'width_w', 'surface_w', 'steps_w', 'slope_w', 'crossing_w', 'length', 'w_length', 'w_length_r', 'w_length_d', 'z-start' ,'z-end','geometry']]

# %% [markdown]
# Visual Checks

# %%
#pedestrian_network.explore(column = 'w_length', tiles = 'cartodbpositron', scheme = 'naturalbreaks')

# %%
#pedestrian_network['slope_w'].value_counts()

# %% [markdown]
# Saving Data

# %%
# #save the data to shapefile
pedestrian_network.to_file('../data/weighted-network/user-group-1/user-group-1-weighted-network.shp')

# %%
# #save also as geojson
pedestrian_network.to_file('../data/paired-data/ug1/network_ug1.geojson', driver='GeoJSON')
